# %%
import pandas as pd

# %%
# # def read_tbl():
# #     df = pd.read_csv("../data/input/training_data.csv")
# #     df = df[~(df.post_middle_name.fillna("") == "")]
# #     return df

# def read_tbl():
#     df = pd.read_csv("../data/input/labeled_data.csv")
#     df = df[~(df.label.fillna("") == "")]
#     return df


# df = read_tbl()

# df

# df.to_csv("../data/output/labeled_data_10_1_2025.csv", index=False)

# %%
df = pd.read_csv("../data/input/california_npi_output.csv")

df = df[df.last_name.fillna("").str.contains(r"GUANZON")]

df
